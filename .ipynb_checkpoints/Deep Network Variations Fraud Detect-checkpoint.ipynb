# %%
import pandas as pd
import pickle 

with open("frames.bin", "rb") as f:
    df = pickle.load(f) 

df = df[df['lon'] != 0]
fraud = df[df['valid'] == 0]
nofraud = df[df['valid'] == 1]
df
# Out:
#             lon      lat  sin_time  cos_time  valid
# 1659   -80.0913  40.4012  0.119415 -0.992844      0
# 497    -77.4874  39.0438 -0.424660 -0.905353      0
# 17622   54.8454  54.8454 -0.254813  0.966990      1
# 3191   -77.4874  39.0438 -0.032792  0.999462      0
# 238   -122.6760  45.5235 -0.423804 -0.905754      0
# ...         ...      ...       ...       ...    ...
# 3303  -121.8950  37.3394  0.675644  0.737228      0
# 16660   54.8865  54.8865 -0.318753  0.947838      1
# 17410   54.2458  54.2458 -0.268429  0.963299      1
# 16454   52.6720  52.6720 -0.349049  0.937104      1
# 17573   51.0942  51.0942 -0.258257  0.966076      1
#
# [4178 rows x 5 columns]

# %%
frames = pd.concat([nofraud, fraud])
train = frames[0:3000]
test  = frames[3000:4000]
x = train.iloc[:,0:4]
y = train.iloc[:,4:5]

tx = test.iloc[:,0:4]
ty = test.iloc[:,4:5]

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout


model = Sequential()
model.add(Dense(12, input_dim=4, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.7))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.7))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x, y, epochs=150, batch_size=10)

_, accuracy = model.evaluate(tx, ty)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Epoch 1/150
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0832 - accuracy: 0.9920
# Epoch 2/150
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 3/150
# 200/200 [==============================] - 0s 996us/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 4/150
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 5/150
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 6/150
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 7/150
# 200/200 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 8/150
# 200/200 [==============================] - 0s 913us/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 9/150
# 200/200 [==============================] - 0s 936us/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 10/150
# ...

# %%
fraud = df[df['valid'] == 0][0:1000]
nofraud = df[df['valid'] == 1]
train = frames[0:2000]
test  = frames[2000:4000]
x = train.iloc[:,0:4]
y = train.iloc[:,4:5]

tx = test.iloc[:,0:4]
ty = test.iloc[:,4:5]
model.fit(x, y, epochs=150, batch_size=10)
_, accuracy = model.evaluate(tx, ty)
# Out:
# Epoch 1/150
# 200/200 [==============================] - 0s 868us/step - loss: 1.4205e-10 - accuracy: 1.0000
# Epoch 2/150
# 200/200 [==============================] - 0s 823us/step - loss: 1.4205e-10 - accuracy: 1.0000
# Epoch 3/150
# 200/200 [==============================] - 0s 753us/step - loss: 1.4205e-10 - accuracy: 1.0000
# Epoch 4/150
# 200/200 [==============================] - 0s 783us/step - loss: 1.4205e-10 - accuracy: 1.0000
# Epoch 5/150
# 200/200 [==============================] - 0s 748us/step - loss: 1.4205e-10 - accuracy: 1.0000
# Epoch 6/150
# 200/200 [==============================] - 0s 823us/step - loss: 1.4205e-10 - accuracy: 1.0000
# Epoch 7/150
# 200/200 [==============================] - 0s 818us/step - loss: 1.4205e-10 - accuracy: 1.0000
# Epoch 8/150
# 200/200 [==============================] - 0s 758us/step - loss: 1.4205e-10 - accuracy: 1.0000
# Epoch 9/150
# 200/200 [==============================] - 0s 758us/step - loss: 1.4205e-10 - accuracy: 1.0000
# ...

# %%
model.fit(x, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0488 - accuracy: 0.9859
# Epoch 2/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0482 - accuracy: 0.9854
# Epoch 3/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0490 - accuracy: 0.9856
# Epoch 4/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0485 - accuracy: 0.9857
# Epoch 5/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0482 - accuracy: 0.9854
# Epoch 6/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0482 - accuracy: 0.9859
# Epoch 7/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0484 - accuracy: 0.9859
# Epoch 8/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0474 - accuracy: 0.9857
# Epoch 9/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0476 - accuracy: 0.9857
# Epoch 10/150
# ...

# %%
_, accuracy = model.evaluate(tx, ty)
# Out:
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9900

# %%
fraud = df[df['valid'] == 0][0:3000]
nofraud = df[df['valid']==1][0:5000]
frames = pd.concat([nofraud, fraud])
train = frames[0:7000]
test  = frames[7000:9000]
x = train.iloc[:,0:4]
y = train.iloc[:,4:5]

tx = test.iloc[:,0:4]
ty = test.iloc[:,4:5]

# %%
model.fit(x, y, epochs=150, batch_size=10)
_, accuracy = model.evaluate(tx, ty)
# Out:
# Epoch 1/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0445 - accuracy: 0.9873
# Epoch 2/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0440 - accuracy: 0.9871
# Epoch 3/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0444 - accuracy: 0.9867
# Epoch 4/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0442 - accuracy: 0.9869
# Epoch 5/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0440 - accuracy: 0.9861
# Epoch 6/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0439 - accuracy: 0.9870
# Epoch 7/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0448 - accuracy: 0.9869
# Epoch 8/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0448 - accuracy: 0.9867
# Epoch 9/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0444 - accuracy: 0.9870
# Epoch 10/150
# ...

# %%
fraud = df[df['valid'] == 0][0:2000]
nofraud = df[df['valid']==1][0:5000]
frames = pd.concat([nofraud, fraud])
train = frames[0:7000]
test  = frames[7000:9000]
x = train.iloc[:,0:4]
y = train.iloc[:,4:5]

tx = test.iloc[:,0:4]
ty = test.iloc[:,4:5] 

model.fit(x, y, epochs=150, batch_size=10)
_, accuracy = model.evaluate(tx, ty)
# Out:
# Epoch 1/150
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0440 - accuracy: 0.9873
# Epoch 2/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0440 - accuracy: 0.9871
# Epoch 3/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0432 - accuracy: 0.9874
# Epoch 4/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0433 - accuracy: 0.9876
# Epoch 5/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0439 - accuracy: 0.9870
# Epoch 6/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0435 - accuracy: 0.9870
# Epoch 7/150
# 700/700 [==============================] - 1s 2ms/step - loss: 0.0433 - accuracy: 0.9869
# Epoch 8/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0432 - accuracy: 0.9874
# Epoch 9/150
# 700/700 [==============================] - 1s 1ms/step - loss: 0.0435 - accuracy: 0.9867
# Epoch 10/150
# ...

# %%
fraud = df[df['valid'] == 0][0:1000]
nofraud = df[df['valid']==1][0:5000]
frames = pd.concat([nofraud, fraud])
train = frames[0:7000]
test  = frames[7000:9000]
x = train.iloc[:,0:4]
y = train.iloc[:,4:5]

tx = test.iloc[:,0:4]
ty = test.iloc[:,4:5] 

model.fit(x, y, epochs=150, batch_size=10)
_, accuracy = model.evaluate(tx, ty)
